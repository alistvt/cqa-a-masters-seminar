# %% [markdown]
# # Intro

# %%
# !pip install nlp
# !pip install transformers
# !pip install datasets
# !pip install wandb

# %%
# MONITOR CPU and GPU
import wandb
wandb.init()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/alfabetxy/uncategorized/runs/2m0prsa3" target="_blank">sandy-feather-6</a></strong> to <a href="https://wandb.ai/alfabetxy/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/alfabetxy/uncategorized/runs/2m0prsa3?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
## IMPORTS
import os
import sys
import logging
from dataclasses import dataclass, field
import json
from typing import Dict, List, Optional

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from tqdm.notebook import tqdm

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

import datasets

from transformers import AutoModelForQuestionAnswering, AutoTokenizer
from transformers import default_data_collator, TrainingArguments, Trainer, EvalPrediction, set_seed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# GLOBAL VARIABLES

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

UNKNOWN = "unknown"
BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/"
DATASET_TRAIN_PATH = "/content/drive/MyDrive/Colab Notebooks/seminar/dataset/coqa_train_ds_512_tokenized"
DATASET_TEST_PATH = "/content/drive/MyDrive/Colab Notebooks/seminar/dataset/coqa_val_ds_512_tokenized"

ANSWERS_PATH = "/content/drive/MyDrive/Colab Notebooks/seminar/answers/{file_name}"

MODEL_NAME = "bert-base-uncased"

SEED = 7

max_length = 512

# %%
print(device)
# Out:
# cuda

# %%
LOGS_DIR = BASE_PATH + "logs/"
MODEL_DIR = BASE_PATH + "model/"
OUTPUT_DIR = BASE_PATH + "output/"
TOKENIZER_DIR = BASE_PATH + "tokenizer/"
DIRECTORIES = [LOGS_DIR, MODEL_DIR, OUTPUT_DIR, TOKENIZER_DIR]

# %%
for direc in DIRECTORIES:
    if not os.path.exists(direc):
        os.makedirs(direc)

# %% [markdown]
# # Prepare Data

# %%
ds_train = datasets.load_from_disk(DATASET_TRAIN_PATH)
ds_val = datasets.load_from_disk(DATASET_TEST_PATH)

# %%
ds_train, ds_val
# Out:
# (Dataset({
#      features: ['attention_mask', 'end_positions', 'input_ids', 'start_positions', 'token_type_ids'],
#      num_rows: 108647
#  }), Dataset({
#      features: ['attention_mask', 'end_positions', 'input_ids', 'start_positions', 'token_type_ids'],
#      num_rows: 7983
#  }))

# %%
# cache the dataset, so we can load it directly for training

# torch.save(dataset_train, 'train_data.pt')
# torch.save(dataset_val, 'valid_data.pt')

# %% [markdown]
# # Model

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForQuestionAnswering.from_pretrained(MODEL_NAME)
data_collator = default_data_collator
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Training script

# %%
model = model.to(device)
set_seed(SEED)

# %%
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds_train,
    eval_dataset=ds_val,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# %%
# trainer.train(resume_from_checkpoint=True)
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 108647
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20373
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/alfabetxy/huggingface/runs/w8ohwm9o" target="_blank">/content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/</a></strong> to <a href="https://wandb.ai/alfabetxy/huggingface" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#     <div>
#
#       <progress value='20374' max='20373' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20373/20373 5:09:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.997100</td>
#       <td>2.768387</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.620900</td>
#       <td>2.715732</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='220' max='499' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [220/499 01:03 < 01:20, 3.46 it/s]
#     </div>
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-6500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 7983
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-7500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-8500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-9500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-10500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-11500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-12500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-13500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 7983
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-14500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-15500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-16500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-17500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-18500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19000/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-19500/special_tokens_map.json
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-20000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-20000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/output/checkpoint-20000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 7983
#   Batch size = 16
#     <div>
#
#       <progress value='20373' max='20373' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20373/20373 5:11:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.997100</td>
#       <td>2.768387</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.620900</td>
#       <td>2.715732</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.339400</td>
#       <td>2.765806</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=20373, training_loss=2.739230358213843, metrics={'train_runtime': 18755.562, 'train_samples_per_second': 17.378, 'train_steps_per_second': 1.086, 'total_flos': 8.516732618728858e+16, 'train_loss': 2.739230358213843, 'epoch': 3.0})

# %%
model.save_pretrained(MODEL_DIR + "3_epochs")
# Out:
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/model/3_epochs/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/seminar/pickle/11/model/3_epochs/pytorch_model.bin

# %%
# set_seed(SEED)

# training_args = TrainingArguments(
#     output_dir="output",
#     overwrite_output_dir = True,
#     evaluation_strategy="epoch",
#     save_strategy="epoch",
#     num_train_epochs = 1,
#     per_device_train_batch_size = 16,
#     per_device_eval_batch_size=8,
#     gradient_accumulation_steps = 8,    
#     eval_steps=500,
#     disable_tqdm = False, 
#     seed=0,
#     load_best_model_at_end=True,
#     # warmup_steps=200,
#     weight_decay=0.01,
#     logging_steps = 4,
#     learning_rate = 1e-4,
#     logging_dir='logs/',
#     run_name = 'finetuning-longformer-on-coqa-flat-no-mlm',
#     do_train = True,
#     prediction_loss_only=True,
#     # fp16 = True,
# ) 

# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=train_dataset,
#     eval_dataset=valid_dataset,
#     data_collator=MyDataCollator(),
#     # compute_metrics 
# )

# %%
# Evaluation
results = {}
if training_args.do_eval and training_args.local_rank in [-1, 0]:
    
    logger.info("*** Evaluate ***")

    eval_output = trainer.evaluate()

    output_eval_file = os.path.join(training_args.output_dir, "eval_results.txt")
    with open(output_eval_file, "w") as writer:
        logger.info("***** Eval results *****")
        for key in sorted(eval_output.keys()):
            logger.info("  %s = %s", key, str(eval_output[key]))
            writer.write("%s = %s\n" % (key, str(eval_output[key])))

    results.update(eval_output)
    
    print(results)

# %% [markdown]
# # Test model with data

# %%
predictions = []

for index, item in tqdm(df_test.iterrows()):

    question, text = item["question"], item["story"]

    encoding = model.tokenizer(question, text, return_tensors="pt").to(device)

    outputs = model(**encoding)
    # outputs = model(**encoding, start_positions=start_positions, end_positions=end_positions)

    answer = model.construct_answer(outputs, encoding)

    predictions.append(
        {
            "id": item["id"],
            "turn_id": item["turn_id"],
            "answer": answer
        }
    )
